# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results__.html
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__notebook__.ipynb
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__output__.json
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/custom.css
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_3.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_4.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_1.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_5.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___34_1.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_6.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___34_3.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_8.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_9.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_2.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_7.png
# /kaggle/input/mvtec-ad-anomaly-detection-with-anomalib-library/__results___files/__results___28_0.png
# /kaggle/input/mvtec-ad/readme.txt
# /kaggle/input/mvtec-ad/license.txt
# /kaggle/input/mvtec-ad/wood/readme.txt
# /kaggle/input/mvtec-ad/wood/license.txt
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/000_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/003_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/004_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/005_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/001_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/006_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/008_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/007_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/002_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/hole/009_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/000_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/003_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/004_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/005_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/001_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/006_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/008_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/007_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/002_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/liquid/009_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/010_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/011_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/020_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/016_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/019_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/000_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/018_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/003_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/012_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/015_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/004_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/005_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/001_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/006_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/008_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/013_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/007_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/014_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/017_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/002_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/scratch/009_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/000_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/003_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/004_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/005_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/001_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/006_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/007_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/color/002_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/010_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/000_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/003_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/004_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/005_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/001_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/006_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/008_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/007_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/002_mask.png
# /kaggle/input/mvtec-ad/wood/ground_truth/combined/009_mask.png
# /kaggle/input/mvtec-ad/wood/test/good/007.png
# /kaggle/input/mvtec-ad/wood/test/good/016.png
# /kaggle/input/mvtec-ad/wood/test/good/005.png
# /kaggle/input/mvtec-ad/wood/test/good/011.png
# /kaggle/input/mvtec-ad/wood/test/good/013.png
# /kaggle/input/mvtec-ad/wood/test/good/017.png
# /kaggle/input/mvtec-ad/wood/test/good/004.png
# /kaggle/input/mvtec-ad/wood/test/good/018.png
# /kaggle/input/mvtec-ad/wood/test/good/002.png
# /kaggle/input/mvtec-ad/wood/test/good/000.png
# /kaggle/input/mvtec-ad/wood/test/good/003.png
# /kaggle/input/mvtec-ad/wood/test/good/015.png
# /kaggle/input/mvtec-ad/wood/test/good/001.png
# /kaggle/input/mvtec-ad/wood/test/good/012.png
# /kaggle/input/mvtec-ad/wood/test/good/009.png
# /kaggle/input/mvtec-ad/wood/test/good/010.png
# /kaggle/input/mvtec-ad/wood/test/good/008.png
# /kaggle/input/mvtec-ad/wood/test/good/006.png
# /kaggle/input/mvtec-ad/wood/test/good/014.png
# /kaggle/input/mvtec-ad/wood/test/hole/007.png
# /kaggle/input/mvtec-ad/wood/test/hole/005.png
# /kaggle/input/mvtec-ad/wood/test/hole/004.png
# /kaggle/input/mvtec-ad/wood/test/hole/002.png
# /kaggle/input/mvtec-ad/wood/test/hole/000.png
# /kaggle/input/mvtec-ad/wood/test/hole/003.png
# /kaggle/input/mvtec-ad/wood/test/hole/001.png
# /kaggle/input/mvtec-ad/wood/test/hole/009.png
# /kaggle/input/mvtec-ad/wood/test/hole/008.png
# /kaggle/input/mvtec-ad/wood/test/hole/006.png
# /kaggle/input/mvtec-ad/wood/test/liquid/007.png
# /kaggle/input/mvtec-ad/wood/test/liquid/005.png
# /kaggle/input/mvtec-ad/wood/test/liquid/004.png
# /kaggle/input/mvtec-ad/wood/test/liquid/002.png
# /kaggle/input/mvtec-ad/wood/test/liquid/000.png
# /kaggle/input/mvtec-ad/wood/test/liquid/003.png
# /kaggle/input/mvtec-ad/wood/test/liquid/001.png
# /kaggle/input/mvtec-ad/wood/test/liquid/009.png
# /kaggle/input/mvtec-ad/wood/test/liquid/008.png
# /kaggle/input/mvtec-ad/wood/test/liquid/006.png
# /kaggle/input/mvtec-ad/wood/test/scratch/007.png
# /kaggle/input/mvtec-ad/wood/test/scratch/016.png
# /kaggle/input/mvtec-ad/wood/test/scratch/005.png
# /kaggle/input/mvtec-ad/wood/test/scratch/011.png
# /kaggle/input/mvtec-ad/wood/test/scratch/013.png
# /kaggle/input/mvtec-ad/wood/test/scratch/017.png
# /kaggle/input/mvtec-ad/wood/test/scratch/004.png
# /kaggle/input/mvtec-ad/wood/test/scratch/018.png
# /kaggle/input/mvtec-ad/wood/test/scratch/002.png
# /kaggle/input/mvtec-ad/wood/test/scratch/020.png
# /kaggle/input/mvtec-ad/wood/test/scratch/000.png
# /kaggle/input/mvtec-ad/wood/test/scratch/019.png
# /kaggle/input/mvtec-ad/wood/test/scratch/003.png
# /kaggle/input/mvtec-ad/wood/test/scratch/015.png
# /kaggle/input/mvtec-ad/wood/test/scratch/001.png
# /kaggle/input/mvtec-ad/wood/test/scratch/012.png
# /kaggle/input/mvtec-ad/wood/test/scratch/009.png
# /kaggle/input/mvtec-ad/wood/test/scratch/010.png
# /kaggle/input/mvtec-ad/wood/test/scratch/008.png
# /kaggle/input/mvtec-ad/wood/test/scratch/006.png
# /kaggle/input/mvtec-ad/wood/test/scratch/014.png
# /kaggle/input/mvtec-ad/wood/test/color/007.png
# /kaggle/input/mvtec-ad/wood/test/color/005.png
# /kaggle/input/mvtec-ad/wood/test/color/004.png
# /kaggle/input/mvtec-ad/wood/test/color/002.png
# /kaggle/input/mvtec-ad/wood/test/color/000.png
# /kaggle/input/mvtec-ad/wood/test/color/003.png
# /kaggle/input/mvtec-ad/wood/test/color/001.png
# /kaggle/input/mvtec-ad/wood/test/color/006.png
# /kaggle/input/mvtec-ad/wood/test/combined/007.png
# /kaggle/input/mvtec-ad/wood/test/combined/005.png
# /kaggle/input/mvtec-ad/wood/test/combined/004.png
# /kaggle/input/mvtec-ad/wood/test/combined/002.png
# /kaggle/input/mvtec-ad/wood/test/combined/000.png
# /kaggle/input/mvtec-ad/wood/test/combined/003.png
# /kaggle/input/mvtec-ad/wood/test/combined/001.png
# /kaggle/input/mvtec-ad/wood/test/combined/009.png
# /kaggle/input/mvtec-ad/wood/test/combined/010.png
# /kaggle/input/mvtec-ad/wood/test/combined/008.png
# /kaggle/input/mvtec-ad/wood/test/combined/006.png
# /kaggle/input/mvtec-ad/wood/train/good/173.png
# /kaggle/input/mvtec-ad/wood/train/good/043.png
# /kaggle/input/mvtec-ad/wood/train/good/038.png
# /kaggle/input/mvtec-ad/wood/train/good/069.png
# /kaggle/input/mvtec-ad/wood/train/good/236.png
# /kaggle/input/mvtec-ad/wood/train/good/083.png
# /kaggle/input/mvtec-ad/wood/train/good/074.png
# /kaggle/input/mvtec-ad/wood/train/good/227.png
# /kaggle/input/mvtec-ad/wood/train/good/238.png
# /kaggle/input/mvtec-ad/wood/train/good/222.png
# /kaggle/input/mvtec-ad/wood/train/good/231.png
# /kaggle/input/mvtec-ad/wood/train/good/027.png
# /kaggle/input/mvtec-ad/wood/train/good/148.png
# /kaggle/input/mvtec-ad/wood/train/good/232.png
# /kaggle/input/mvtec-ad/wood/train/good/177.png
# /kaggle/input/mvtec-ad/wood/train/good/142.png
# /kaggle/input/mvtec-ad/wood/train/good/104.png
# /kaggle/input/mvtec-ad/wood/train/good/053.png
# /kaggle/input/mvtec-ad/wood/train/good/007.png
# /kaggle/input/mvtec-ad/wood/train/good/133.png
# /kaggle/input/mvtec-ad/wood/train/good/162.png
# /kaggle/input/mvtec-ad/wood/train/good/186.png
# /kaggle/input/mvtec-ad/wood/train/good/089.png
# /kaggle/input/mvtec-ad/wood/train/good/153.png
# /kaggle/input/mvtec-ad/wood/train/good/023.png
# /kaggle/input/mvtec-ad/wood/train/good/167.png
# /kaggle/input/mvtec-ad/wood/train/good/092.png
# /kaggle/input/mvtec-ad/wood/train/good/061.png
# /kaggle/input/mvtec-ad/wood/train/good/204.png
# /kaggle/input/mvtec-ad/wood/train/good/016.png
# /kaggle/input/mvtec-ad/wood/train/good/081.png
# /kaggle/input/mvtec-ad/wood/train/good/005.png
# /kaggle/input/mvtec-ad/wood/train/good/031.png
# /kaggle/input/mvtec-ad/wood/train/good/164.png
# /kaggle/input/mvtec-ad/wood/train/good/011.png
# /kaggle/input/mvtec-ad/wood/train/good/213.png
# /kaggle/input/mvtec-ad/wood/train/good/114.png
# /kaggle/input/mvtec-ad/wood/train/good/185.png
# /kaggle/input/mvtec-ad/wood/train/good/240.png
# /kaggle/input/mvtec-ad/wood/train/good/013.png
# /kaggle/input/mvtec-ad/wood/train/good/176.png
# /kaggle/input/mvtec-ad/wood/train/good/124.png
# /kaggle/input/mvtec-ad/wood/train/good/119.png
# /kaggle/input/mvtec-ad/wood/train/good/046.png
# /kaggle/input/mvtec-ad/wood/train/good/100.png
# /kaggle/input/mvtec-ad/wood/train/good/211.png
# /kaggle/input/mvtec-ad/wood/train/good/193.png
# /kaggle/input/mvtec-ad/wood/train/good/191.png
# /kaggle/input/mvtec-ad/wood/train/good/039.png
# /kaggle/input/mvtec-ad/wood/train/good/163.png
# /kaggle/input/mvtec-ad/wood/train/good/042.png
# /kaggle/input/mvtec-ad/wood/train/good/138.png
# /kaggle/input/mvtec-ad/wood/train/good/024.png
# /kaggle/input/mvtec-ad/wood/train/good/052.png
# /kaggle/input/mvtec-ad/wood/train/good/225.png
# /kaggle/input/mvtec-ad/wood/train/good/057.png
# /kaggle/input/mvtec-ad/wood/train/good/192.png
# /kaggle/input/mvtec-ad/wood/train/good/229.png
# /kaggle/input/mvtec-ad/wood/train/good/090.png
# /kaggle/input/mvtec-ad/wood/train/good/025.png
# /kaggle/input/mvtec-ad/wood/train/good/129.png
# /kaggle/input/mvtec-ad/wood/train/good/017.png
# /kaggle/input/mvtec-ad/wood/train/good/171.png
# /kaggle/input/mvtec-ad/wood/train/good/145.png
# /kaggle/input/mvtec-ad/wood/train/good/209.png
# /kaggle/input/mvtec-ad/wood/train/good/197.png
# /kaggle/input/mvtec-ad/wood/train/good/126.png
# /kaggle/input/mvtec-ad/wood/train/good/147.png
# /kaggle/input/mvtec-ad/wood/train/good/075.png
# /kaggle/input/mvtec-ad/wood/train/good/102.png
# /kaggle/input/mvtec-ad/wood/train/good/245.png
# /kaggle/input/mvtec-ad/wood/train/good/168.png
# /kaggle/input/mvtec-ad/wood/train/good/054.png
# /kaggle/input/mvtec-ad/wood/train/good/233.png
# /kaggle/input/mvtec-ad/wood/train/good/200.png
# /kaggle/input/mvtec-ad/wood/train/good/067.png
# /kaggle/input/mvtec-ad/wood/train/good/004.png
# /kaggle/input/mvtec-ad/wood/train/good/033.png
# /kaggle/input/mvtec-ad/wood/train/good/116.png
# /kaggle/input/mvtec-ad/wood/train/good/130.png
# /kaggle/input/mvtec-ad/wood/train/good/091.png
# /kaggle/input/mvtec-ad/wood/train/good/218.png
# /kaggle/input/mvtec-ad/wood/train/good/199.png
# /kaggle/input/mvtec-ad/wood/train/good/112.png
# /kaggle/input/mvtec-ad/wood/train/good/049.png
# /kaggle/input/mvtec-ad/wood/train/good/150.png
# /kaggle/input/mvtec-ad/wood/train/good/070.png
# /kaggle/input/mvtec-ad/wood/train/good/064.png
# /kaggle/input/mvtec-ad/wood/train/good/113.png
# /kaggle/input/mvtec-ad/wood/train/good/169.png
# /kaggle/input/mvtec-ad/wood/train/good/170.png
# /kaggle/input/mvtec-ad/wood/train/good/194.png
# /kaggle/input/mvtec-ad/wood/train/good/136.png
# /kaggle/input/mvtec-ad/wood/train/good/018.png
# /kaggle/input/mvtec-ad/wood/train/good/198.png
# /kaggle/input/mvtec-ad/wood/train/good/045.png
# /kaggle/input/mvtec-ad/wood/train/good/161.png
# /kaggle/input/mvtec-ad/wood/train/good/002.png
# /kaggle/input/mvtec-ad/wood/train/good/108.png
# /kaggle/input/mvtec-ad/wood/train/good/093.png
# /kaggle/input/mvtec-ad/wood/train/good/132.png
# /kaggle/input/mvtec-ad/wood/train/good/156.png
# /kaggle/input/mvtec-ad/wood/train/good/040.png
# /kaggle/input/mvtec-ad/wood/train/good/035.png
# /kaggle/input/mvtec-ad/wood/train/good/094.png
# /kaggle/input/mvtec-ad/wood/train/good/107.png
# /kaggle/input/mvtec-ad/wood/train/good/215.png
# /kaggle/input/mvtec-ad/wood/train/good/181.png
# /kaggle/input/mvtec-ad/wood/train/good/151.png
# /kaggle/input/mvtec-ad/wood/train/good/068.png
# /kaggle/input/mvtec-ad/wood/train/good/048.png
# /kaggle/input/mvtec-ad/wood/train/good/223.png
# /kaggle/input/mvtec-ad/wood/train/good/020.png
# /kaggle/input/mvtec-ad/wood/train/good/242.png
# /kaggle/input/mvtec-ad/wood/train/good/174.png
# /kaggle/input/mvtec-ad/wood/train/good/071.png
# /kaggle/input/mvtec-ad/wood/train/good/131.png
# /kaggle/input/mvtec-ad/wood/train/good/041.png
# /kaggle/input/mvtec-ad/wood/train/good/157.png
# /kaggle/input/mvtec-ad/wood/train/good/182.png
# /kaggle/input/mvtec-ad/wood/train/good/143.png
# /kaggle/input/mvtec-ad/wood/train/good/034.png
# /kaggle/input/mvtec-ad/wood/train/good/221.png
# /kaggle/input/mvtec-ad/wood/train/good/208.png
# /kaggle/input/mvtec-ad/wood/train/good/152.png
# /kaggle/input/mvtec-ad/wood/train/good/137.png
# /kaggle/input/mvtec-ad/wood/train/good/076.png
# /kaggle/input/mvtec-ad/wood/train/good/239.png
# /kaggle/input/mvtec-ad/wood/train/good/079.png
# /kaggle/input/mvtec-ad/wood/train/good/214.png
# /kaggle/input/mvtec-ad/wood/train/good/122.png
# /kaggle/input/mvtec-ad/wood/train/good/051.png
# /kaggle/input/mvtec-ad/wood/train/good/187.png
# /kaggle/input/mvtec-ad/wood/train/good/106.png
# /kaggle/input/mvtec-ad/wood/train/good/117.png
# /kaggle/input/mvtec-ad/wood/train/good/220.png
# /kaggle/input/mvtec-ad/wood/train/good/032.png
# /kaggle/input/mvtec-ad/wood/train/good/095.png
# /kaggle/input/mvtec-ad/wood/train/good/244.png
# /kaggle/input/mvtec-ad/wood/train/good/055.png
# /kaggle/input/mvtec-ad/wood/train/good/037.png
# /kaggle/input/mvtec-ad/wood/train/good/166.png
# /kaggle/input/mvtec-ad/wood/train/good/029.png
# /kaggle/input/mvtec-ad/wood/train/good/088.png
# /kaggle/input/mvtec-ad/wood/train/good/028.png
# /kaggle/input/mvtec-ad/wood/train/good/026.png
# /kaggle/input/mvtec-ad/wood/train/good/066.png
# /kaggle/input/mvtec-ad/wood/train/good/127.png
# /kaggle/input/mvtec-ad/wood/train/good/219.png
# /kaggle/input/mvtec-ad/wood/train/good/073.png
# /kaggle/input/mvtec-ad/wood/train/good/184.png
# /kaggle/input/mvtec-ad/wood/train/good/000.png
# /kaggle/input/mvtec-ad/wood/train/good/019.png
# /kaggle/input/mvtec-ad/wood/train/good/003.png
# /kaggle/input/mvtec-ad/wood/train/good/036.png
# /kaggle/input/mvtec-ad/wood/train/good/190.png
# /kaggle/input/mvtec-ad/wood/train/good/165.png
# /kaggle/input/mvtec-ad/wood/train/good/015.png
# /kaggle/input/mvtec-ad/wood/train/good/202.png
# /kaggle/input/mvtec-ad/wood/train/good/243.png
# /kaggle/input/mvtec-ad/wood/train/good/060.png
# /kaggle/input/mvtec-ad/wood/train/good/159.png
# /kaggle/input/mvtec-ad/wood/train/good/246.png
# /kaggle/input/mvtec-ad/wood/train/good/195.png
# /kaggle/input/mvtec-ad/wood/train/good/105.png
# /kaggle/input/mvtec-ad/wood/train/good/125.png
# /kaggle/input/mvtec-ad/wood/train/good/121.png
# /kaggle/input/mvtec-ad/wood/train/good/216.png
# /kaggle/input/mvtec-ad/wood/train/good/146.png
# /kaggle/input/mvtec-ad/wood/train/good/154.png
# /kaggle/input/mvtec-ad/wood/train/good/063.png
# /kaggle/input/mvtec-ad/wood/train/good/022.png
# /kaggle/input/mvtec-ad/wood/train/good/241.png
# /kaggle/input/mvtec-ad/wood/train/good/188.png
# /kaggle/input/mvtec-ad/wood/train/good/030.png
# /kaggle/input/mvtec-ad/wood/train/good/103.png
# /kaggle/input/mvtec-ad/wood/train/good/144.png
# /kaggle/input/mvtec-ad/wood/train/good/109.png
# /kaggle/input/mvtec-ad/wood/train/good/224.png
# /kaggle/input/mvtec-ad/wood/train/good/080.png
# /kaggle/input/mvtec-ad/wood/train/good/120.png
# /kaggle/input/mvtec-ad/wood/train/good/118.png
# /kaggle/input/mvtec-ad/wood/train/good/056.png
# /kaggle/input/mvtec-ad/wood/train/good/078.png
# /kaggle/input/mvtec-ad/wood/train/good/072.png
# /kaggle/input/mvtec-ad/wood/train/good/196.png
# /kaggle/input/mvtec-ad/wood/train/good/044.png
# /kaggle/input/mvtec-ad/wood/train/good/179.png
# /kaggle/input/mvtec-ad/wood/train/good/178.png
# /kaggle/input/mvtec-ad/wood/train/good/086.png
# /kaggle/input/mvtec-ad/wood/train/good/160.png
# /kaggle/input/mvtec-ad/wood/train/good/140.png
# /kaggle/input/mvtec-ad/wood/train/good/139.png
# /kaggle/input/mvtec-ad/wood/train/good/172.png
# /kaggle/input/mvtec-ad/wood/train/good/001.png
# /kaggle/input/mvtec-ad/wood/train/good/047.png
# /kaggle/input/mvtec-ad/wood/train/good/097.png
# /kaggle/input/mvtec-ad/wood/train/good/203.png
# /kaggle/input/mvtec-ad/wood/train/good/087.png
# /kaggle/input/mvtec-ad/wood/train/good/077.png
# /kaggle/input/mvtec-ad/wood/train/good/115.png
# /kaggle/input/mvtec-ad/wood/train/good/128.png
# /kaggle/input/mvtec-ad/wood/train/good/158.png
# /kaggle/input/mvtec-ad/wood/train/good/012.png
# /kaggle/input/mvtec-ad/wood/train/good/085.png
# /kaggle/input/mvtec-ad/wood/train/good/082.png
# /kaggle/input/mvtec-ad/wood/train/good/101.png
# /kaggle/input/mvtec-ad/wood/train/good/009.png
# /kaggle/input/mvtec-ad/wood/train/good/135.png
# /kaggle/input/mvtec-ad/wood/train/good/065.png
# /kaggle/input/mvtec-ad/wood/train/good/123.png
# /kaggle/input/mvtec-ad/wood/train/good/230.png
# /kaggle/input/mvtec-ad/wood/train/good/189.png
# /kaggle/input/mvtec-ad/wood/train/good/059.png
# /kaggle/input/mvtec-ad/wood/train/good/180.png
# /kaggle/input/mvtec-ad/wood/train/good/062.png
# /kaggle/input/mvtec-ad/wood/train/good/210.png
# /kaggle/input/mvtec-ad/wood/train/good/234.png
# /kaggle/input/mvtec-ad/wood/train/good/183.png
# /kaggle/input/mvtec-ad/wood/train/good/098.png
# /kaggle/input/mvtec-ad/wood/train/good/096.png
# /kaggle/input/mvtec-ad/wood/train/good/235.png
# /kaggle/input/mvtec-ad/wood/train/good/155.png
# /kaggle/input/mvtec-ad/wood/train/good/228.png
# /kaggle/input/mvtec-ad/wood/train/good/237.png
# /kaggle/input/mvtec-ad/wood/train/good/201.png
# /kaggle/input/mvtec-ad/wood/train/good/212.png
# /kaggle/input/mvtec-ad/wood/train/good/207.png
# /kaggle/input/mvtec-ad/wood/train/good/149.png
# /kaggle/input/mvtec-ad/wood/train/good/084.png
# /kaggle/input/mvtec-ad/wood/train/good/099.png
# /kaggle/input/mvtec-ad/wood/train/good/206.png
# /kaggle/input/mvtec-ad/wood/train/good/050.png
# /kaggle/input/mvtec-ad/wood/train/good/010.png
# /kaggle/input/mvtec-ad/wood/train/good/021.png
# /kaggle/input/mvtec-ad/wood/train/good/134.png
# /kaggle/input/mvtec-ad/wood/train/good/111.png
# /kaggle/input/mvtec-ad/wood/train/good/205.png
# /kaggle/input/mvtec-ad/wood/train/good/141.png
# /kaggle/input/mvtec-ad/wood/train/good/110.png
# /kaggle/input/mvtec-ad/wood/train/good/008.png
# /kaggle/input/mvtec-ad/wood/train/good/006.png
# /kaggle/input/mvtec-ad/wood/train/good/058.png
# /kaggle/input/mvtec-ad/wood/train/good/175.png
# /kaggle/input/mvtec-ad/wood/train/good/014.png
# /kaggle/input/mvtec-ad/wood/train/good/226.png
# /kaggle/input/mvtec-ad/wood/train/good/217.png
# /kaggle/input/mvtec-ad/screw/readme.txt
# /kaggle/input/mvtec-ad/screw/license.txt
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/010_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/011_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/020_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/016_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/019_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/021_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/000_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/018_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/003_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/012_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/015_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/004_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/005_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/022_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/001_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/006_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/008_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/013_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/007_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/014_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/017_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/002_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_top/009_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/010_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/011_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/020_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/016_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/019_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/021_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/000_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/023_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/018_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/003_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/012_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/015_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/024_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/004_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/005_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/022_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/001_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/006_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/008_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/013_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/007_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/014_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/017_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/002_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_neck/009_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/010_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/011_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/020_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/016_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/019_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/021_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/000_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/018_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/003_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/012_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/015_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/004_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/005_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/022_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/001_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/006_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/008_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/013_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/007_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/014_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/017_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/002_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/thread_side/009_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/010_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/011_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/020_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/016_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/019_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/021_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/000_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/023_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/018_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/003_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/012_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/015_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/004_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/005_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/022_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/001_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/006_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/008_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/013_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/007_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/014_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/017_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/002_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/scratch_head/009_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/010_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/011_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/020_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/016_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/019_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/021_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/000_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/023_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/018_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/003_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/012_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/015_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/004_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/005_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/022_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/001_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/006_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/008_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/013_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/007_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/014_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/017_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/002_mask.png
# /kaggle/input/mvtec-ad/screw/ground_truth/manipulated_front/009_mask.png
# /kaggle/input/mvtec-ad/screw/test/good/038.png
# /kaggle/input/mvtec-ad/screw/test/good/027.png
# /kaggle/input/mvtec-ad/screw/test/good/007.png
# /kaggle/input/mvtec-ad/screw/test/good/023.png
# /kaggle/input/mvtec-ad/screw/test/good/016.png
# /kaggle/input/mvtec-ad/screw/test/good/005.png
# /kaggle/input/mvtec-ad/screw/test/good/031.png
# /kaggle/input/mvtec-ad/screw/test/good/011.png
# /kaggle/input/mvtec-ad/screw/test/good/013.png
# /kaggle/input/mvtec-ad/screw/test/good/039.png
# /kaggle/input/mvtec-ad/screw/test/good/024.png
# /kaggle/input/mvtec-ad/screw/test/good/025.png
# /kaggle/input/mvtec-ad/screw/test/good/017.png
# /kaggle/input/mvtec-ad/screw/test/good/004.png
# /kaggle/input/mvtec-ad/screw/test/good/033.png
# /kaggle/input/mvtec-ad/screw/test/good/018.png
# /kaggle/input/mvtec-ad/screw/test/good/002.png
# /kaggle/input/mvtec-ad/screw/test/good/040.png
# /kaggle/input/mvtec-ad/screw/test/good/035.png
# /kaggle/input/mvtec-ad/screw/test/good/020.png
# /kaggle/input/mvtec-ad/screw/test/good/034.png
# /kaggle/input/mvtec-ad/screw/test/good/032.png
# /kaggle/input/mvtec-ad/screw/test/good/037.png
# /kaggle/input/mvtec-ad/screw/test/good/029.png
# /kaggle/input/mvtec-ad/screw/test/good/028.png
# /kaggle/input/mvtec-ad/screw/test/good/026.png
# /kaggle/input/mvtec-ad/screw/test/good/000.png
# /kaggle/input/mvtec-ad/screw/test/good/019.png
# /kaggle/input/mvtec-ad/screw/test/good/003.png
# /kaggle/input/mvtec-ad/screw/test/good/036.png
# /kaggle/input/mvtec-ad/screw/test/good/015.png
# /kaggle/input/mvtec-ad/screw/test/good/022.png
# /kaggle/input/mvtec-ad/screw/test/good/030.png
# /kaggle/input/mvtec-ad/screw/test/good/001.png
# /kaggle/input/mvtec-ad/screw/test/good/012.png
# /kaggle/input/mvtec-ad/screw/test/good/009.png
# /kaggle/input/mvtec-ad/screw/test/good/010.png
# /kaggle/input/mvtec-ad/screw/test/good/021.png
# /kaggle/input/mvtec-ad/screw/test/good/008.png
# /kaggle/input/mvtec-ad/screw/test/good/006.png
# /kaggle/input/mvtec-ad/screw/test/good/014.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/007.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/016.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/005.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/011.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/013.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/017.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/004.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/018.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/002.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/020.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/000.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/019.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/003.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/015.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/022.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/001.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/012.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/009.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/010.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/021.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/008.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/006.png
# /kaggle/input/mvtec-ad/screw/test/thread_top/014.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/007.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/023.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/016.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/005.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/011.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/013.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/024.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/017.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/004.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/018.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/002.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/020.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/000.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/019.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/003.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/015.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/022.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/001.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/012.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/009.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/010.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/021.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/008.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/006.png
# /kaggle/input/mvtec-ad/screw/test/scratch_neck/014.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/007.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/016.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/005.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/011.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/013.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/017.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/004.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/018.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/002.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/020.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/000.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/019.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/003.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/015.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/022.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/001.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/012.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/009.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/010.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/021.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/008.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/006.png
# /kaggle/input/mvtec-ad/screw/test/thread_side/014.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/007.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/023.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/016.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/005.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/011.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/013.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/017.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/004.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/018.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/002.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/020.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/000.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/019.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/003.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/015.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/022.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/001.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/012.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/009.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/010.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/021.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/008.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/006.png
# /kaggle/input/mvtec-ad/screw/test/scratch_head/014.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/007.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/023.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/016.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/005.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/011.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/013.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/017.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/004.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/018.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/002.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/020.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/000.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/019.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/003.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/015.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/022.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/001.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/012.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/009.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/010.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/021.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/008.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/006.png
# /kaggle/input/mvtec-ad/screw/test/manipulated_front/014.png
# /kaggle/input/mvtec-ad/screw/train/good/173.png
# /kaggle/input/mvtec-ad/screw/train/good/043.png
# /kaggle/input/mvtec-ad/screw/train/good/248.png
# /kaggle/input/mvtec-ad/screw/train/good/038.png
# /kaggle/input/mvtec-ad/screw/train/good/069.png
# /kaggle/input/mvtec-ad/screw/train/good/236.png
# /kaggle/input/mvtec-ad/screw/train/good/083.png
# /kaggle/input/mvtec-ad/screw/train/good/074.png
# /kaggle/input/mvtec-ad/screw/train/good/314.png
# /kaggle/input/mvtec-ad/screw/train/good/227.png
# /kaggle/input/mvtec-ad/screw/train/good/238.png
# /kaggle/input/mvtec-ad/screw/train/good/222.png
# /kaggle/input/mvtec-ad/screw/train/good/278.png
# /kaggle/input/mvtec-ad/screw/train/good/303.png
# /kaggle/input/mvtec-ad/screw/train/good/231.png
# /kaggle/input/mvtec-ad/screw/train/good/027.png
# /kaggle/input/mvtec-ad/screw/train/good/148.png
# /kaggle/input/mvtec-ad/screw/train/good/232.png
# /kaggle/input/mvtec-ad/screw/train/good/177.png
# /kaggle/input/mvtec-ad/screw/train/good/142.png
# /kaggle/input/mvtec-ad/screw/train/good/104.png
# /kaggle/input/mvtec-ad/screw/train/good/053.png
# /kaggle/input/mvtec-ad/screw/train/good/007.png
# /kaggle/input/mvtec-ad/screw/train/good/133.png
# /kaggle/input/mvtec-ad/screw/train/good/162.png
# /kaggle/input/mvtec-ad/screw/train/good/186.png
# /kaggle/input/mvtec-ad/screw/train/good/315.png
# /kaggle/input/mvtec-ad/screw/train/good/089.png
# /kaggle/input/mvtec-ad/screw/train/good/261.png
# /kaggle/input/mvtec-ad/screw/train/good/153.png
# /kaggle/input/mvtec-ad/screw/train/good/023.png
# /kaggle/input/mvtec-ad/screw/train/good/167.png
# /kaggle/input/mvtec-ad/screw/train/good/092.png
# /kaggle/input/mvtec-ad/screw/train/good/061.png
# /kaggle/input/mvtec-ad/screw/train/good/204.png
# /kaggle/input/mvtec-ad/screw/train/good/296.png
# /kaggle/input/mvtec-ad/screw/train/good/016.png
# /kaggle/input/mvtec-ad/screw/train/good/081.png
# /kaggle/input/mvtec-ad/screw/train/good/005.png
# /kaggle/input/mvtec-ad/screw/train/good/270.png
# /kaggle/input/mvtec-ad/screw/train/good/031.png
# /kaggle/input/mvtec-ad/screw/train/good/164.png
# /kaggle/input/mvtec-ad/screw/train/good/011.png
# /kaggle/input/mvtec-ad/screw/train/good/213.png
# /kaggle/input/mvtec-ad/screw/train/good/114.png
# /kaggle/input/mvtec-ad/screw/train/good/302.png
# /kaggle/input/mvtec-ad/screw/train/good/185.png
# /kaggle/input/mvtec-ad/screw/train/good/240.png
# /kaggle/input/mvtec-ad/screw/train/good/317.png
# /kaggle/input/mvtec-ad/screw/train/good/281.png
# /kaggle/input/mvtec-ad/screw/train/good/013.png
# /kaggle/input/mvtec-ad/screw/train/good/176.png
# /kaggle/input/mvtec-ad/screw/train/good/124.png
# /kaggle/input/mvtec-ad/screw/train/good/119.png
# /kaggle/input/mvtec-ad/screw/train/good/046.png
# /kaggle/input/mvtec-ad/screw/train/good/256.png
# /kaggle/input/mvtec-ad/screw/train/good/100.png
# /kaggle/input/mvtec-ad/screw/train/good/211.png
# /kaggle/input/mvtec-ad/screw/train/good/193.png
# /kaggle/input/mvtec-ad/screw/train/good/191.png
# /kaggle/input/mvtec-ad/screw/train/good/039.png
# /kaggle/input/mvtec-ad/screw/train/good/163.png
# /kaggle/input/mvtec-ad/screw/train/good/042.png
# /kaggle/input/mvtec-ad/screw/train/good/138.png
# /kaggle/input/mvtec-ad/screw/train/good/024.png
# /kaggle/input/mvtec-ad/screw/train/good/052.png
# /kaggle/input/mvtec-ad/screw/train/good/225.png
# /kaggle/input/mvtec-ad/screw/train/good/057.png
# /kaggle/input/mvtec-ad/screw/train/good/192.png
# /kaggle/input/mvtec-ad/screw/train/good/229.png
# /kaggle/input/mvtec-ad/screw/train/good/090.png
# /kaggle/input/mvtec-ad/screw/train/good/025.png
# /kaggle/input/mvtec-ad/screw/train/good/129.png
# /kaggle/input/mvtec-ad/screw/train/good/017.png
# /kaggle/input/mvtec-ad/screw/train/good/313.png
# /kaggle/input/mvtec-ad/screw/train/good/171.png
# /kaggle/input/mvtec-ad/screw/train/good/287.png
# /kaggle/input/mvtec-ad/screw/train/good/145.png
# /kaggle/input/mvtec-ad/screw/train/good/209.png
# /kaggle/input/mvtec-ad/screw/train/good/197.png
# /kaggle/input/mvtec-ad/screw/train/good/311.png
# /kaggle/input/mvtec-ad/screw/train/good/126.png
# /kaggle/input/mvtec-ad/screw/train/good/147.png
# /kaggle/input/mvtec-ad/screw/train/good/075.png
# /kaggle/input/mvtec-ad/screw/train/good/102.png
# /kaggle/input/mvtec-ad/screw/train/good/254.png
# /kaggle/input/mvtec-ad/screw/train/good/245.png
# /kaggle/input/mvtec-ad/screw/train/good/168.png
# /kaggle/input/mvtec-ad/screw/train/good/054.png
# /kaggle/input/mvtec-ad/screw/train/good/233.png
# /kaggle/input/mvtec-ad/screw/train/good/200.png
# /kaggle/input/mvtec-ad/screw/train/good/255.png
# /kaggle/input/mvtec-ad/screw/train/good/284.png
# /kaggle/input/mvtec-ad/screw/train/good/067.png
# /kaggle/input/mvtec-ad/screw/train/good/004.png
# /kaggle/input/mvtec-ad/screw/train/good/033.png
# /kaggle/input/mvtec-ad/screw/train/good/116.png
# /kaggle/input/mvtec-ad/screw/train/good/299.png
# /kaggle/input/mvtec-ad/screw/train/good/280.png
# /kaggle/input/mvtec-ad/screw/train/good/130.png
# /kaggle/input/mvtec-ad/screw/train/good/291.png
# /kaggle/input/mvtec-ad/screw/train/good/091.png
# /kaggle/input/mvtec-ad/screw/train/good/288.png
# /kaggle/input/mvtec-ad/screw/train/good/307.png
# /kaggle/input/mvtec-ad/screw/train/good/218.png
# /kaggle/input/mvtec-ad/screw/train/good/199.png
# /kaggle/input/mvtec-ad/screw/train/good/112.png
# /kaggle/input/mvtec-ad/screw/train/good/049.png
# /kaggle/input/mvtec-ad/screw/train/good/268.png
# /kaggle/input/mvtec-ad/screw/train/good/150.png
# /kaggle/input/mvtec-ad/screw/train/good/070.png
# /kaggle/input/mvtec-ad/screw/train/good/064.png
# /kaggle/input/mvtec-ad/screw/train/good/113.png
# /kaggle/input/mvtec-ad/screw/train/good/316.png
# /kaggle/input/mvtec-ad/screw/train/good/169.png
# /kaggle/input/mvtec-ad/screw/train/good/301.png
# /kaggle/input/mvtec-ad/screw/train/good/289.png
# /kaggle/input/mvtec-ad/screw/train/good/170.png
# /kaggle/input/mvtec-ad/screw/train/good/194.png
# /kaggle/input/mvtec-ad/screw/train/good/136.png
# /kaggle/input/mvtec-ad/screw/train/good/018.png
# /kaggle/input/mvtec-ad/screw/train/good/198.png
# /kaggle/input/mvtec-ad/screw/train/good/045.png
# /kaggle/input/mvtec-ad/screw/train/good/161.png
# /kaggle/input/mvtec-ad/screw/train/good/293.png
# /kaggle/input/mvtec-ad/screw/train/good/002.png
# /kaggle/input/mvtec-ad/screw/train/good/108.png
# /kaggle/input/mvtec-ad/screw/train/good/093.png
# /kaggle/input/mvtec-ad/screw/train/good/132.png
# /kaggle/input/mvtec-ad/screw/train/good/156.png
# /kaggle/input/mvtec-ad/screw/train/good/040.png
# /kaggle/input/mvtec-ad/screw/train/good/035.png
# /kaggle/input/mvtec-ad/screw/train/good/319.png
# /kaggle/input/mvtec-ad/screw/train/good/094.png
# /kaggle/input/mvtec-ad/screw/train/good/107.png
# /kaggle/input/mvtec-ad/screw/train/good/262.png
# /kaggle/input/mvtec-ad/screw/train/good/215.png
# /kaggle/input/mvtec-ad/screw/train/good/181.png
# /kaggle/input/mvtec-ad/screw/train/good/151.png
# /kaggle/input/mvtec-ad/screw/train/good/068.png
# /kaggle/input/mvtec-ad/screw/train/good/048.png
# /kaggle/input/mvtec-ad/screw/train/good/223.png
# /kaggle/input/mvtec-ad/screw/train/good/020.png
# /kaggle/input/mvtec-ad/screw/train/good/272.png
# /kaggle/input/mvtec-ad/screw/train/good/242.png
# /kaggle/input/mvtec-ad/screw/train/good/251.png
# /kaggle/input/mvtec-ad/screw/train/good/174.png
# /kaggle/input/mvtec-ad/screw/train/good/250.png
# /kaggle/input/mvtec-ad/screw/train/good/071.png
# /kaggle/input/mvtec-ad/screw/train/good/131.png
# /kaggle/input/mvtec-ad/screw/train/good/041.png
# /kaggle/input/mvtec-ad/screw/train/good/157.png
# /kaggle/input/mvtec-ad/screw/train/good/182.png
# /kaggle/input/mvtec-ad/screw/train/good/143.png
# /kaggle/input/mvtec-ad/screw/train/good/034.png
# /kaggle/input/mvtec-ad/screw/train/good/221.png
# /kaggle/input/mvtec-ad/screw/train/good/208.png
# /kaggle/input/mvtec-ad/screw/train/good/152.png
# /kaggle/input/mvtec-ad/screw/train/good/137.png
# /kaggle/input/mvtec-ad/screw/train/good/312.png
# /kaggle/input/mvtec-ad/screw/train/good/076.png
# /kaggle/input/mvtec-ad/screw/train/good/239.png
# /kaggle/input/mvtec-ad/screw/train/good/079.png
# /kaggle/input/mvtec-ad/screw/train/good/214.png
# /kaggle/input/mvtec-ad/screw/train/good/122.png
# /kaggle/input/mvtec-ad/screw/train/good/276.png
# /kaggle/input/mvtec-ad/screw/train/good/051.png
# /kaggle/input/mvtec-ad/screw/train/good/187.png
# /kaggle/input/mvtec-ad/screw/train/good/106.png
# /kaggle/input/mvtec-ad/screw/train/good/279.png
# /kaggle/input/mvtec-ad/screw/train/good/117.png
# /kaggle/input/mvtec-ad/screw/train/good/220.png
# /kaggle/input/mvtec-ad/screw/train/good/277.png
# /kaggle/input/mvtec-ad/screw/train/good/032.png
# /kaggle/input/mvtec-ad/screw/train/good/300.png
# /kaggle/input/mvtec-ad/screw/train/good/095.png
# /kaggle/input/mvtec-ad/screw/train/good/244.png
# /kaggle/input/mvtec-ad/screw/train/good/282.png
# /kaggle/input/mvtec-ad/screw/train/good/263.png
# /kaggle/input/mvtec-ad/screw/train/good/055.png
# /kaggle/input/mvtec-ad/screw/train/good/037.png
# /kaggle/input/mvtec-ad/screw/train/good/166.png
# /kaggle/input/mvtec-ad/screw/train/good/029.png
# /kaggle/input/mvtec-ad/screw/train/good/294.png
# /kaggle/input/mvtec-ad/screw/train/good/088.png
# /kaggle/input/mvtec-ad/screw/train/good/264.png
# /kaggle/input/mvtec-ad/screw/train/good/028.png
# /kaggle/input/mvtec-ad/screw/train/good/026.png
# /kaggle/input/mvtec-ad/screw/train/good/066.png
# /kaggle/input/mvtec-ad/screw/train/good/127.png
# /kaggle/input/mvtec-ad/screw/train/good/219.png
# /kaggle/input/mvtec-ad/screw/train/good/073.png
# /kaggle/input/mvtec-ad/screw/train/good/184.png
# /kaggle/input/mvtec-ad/screw/train/good/000.png
# /kaggle/input/mvtec-ad/screw/train/good/019.png
# /kaggle/input/mvtec-ad/screw/train/good/003.png
# /kaggle/input/mvtec-ad/screw/train/good/036.png
# /kaggle/input/mvtec-ad/screw/train/good/190.png
# /kaggle/input/mvtec-ad/screw/train/good/165.png
# /kaggle/input/mvtec-ad/screw/train/good/015.png
# /kaggle/input/mvtec-ad/screw/train/good/202.png
# /kaggle/input/mvtec-ad/screw/train/good/247.png
# /kaggle/input/mvtec-ad/screw/train/good/243.png
# /kaggle/input/mvtec-ad/screw/train/good/060.png
# /kaggle/input/mvtec-ad/screw/train/good/159.png
# /kaggle/input/mvtec-ad/screw/train/good/246.png
# /kaggle/input/mvtec-ad/screw/train/good/195.png
# /kaggle/input/mvtec-ad/screw/train/good/105.png
# /kaggle/input/mvtec-ad/screw/train/good/125.png
# /kaggle/input/mvtec-ad/screw/train/good/121.png
# /kaggle/input/mvtec-ad/screw/train/good/318.png
# /kaggle/input/mvtec-ad/screw/train/good/216.png
# /kaggle/input/mvtec-ad/screw/train/good/146.png
# /kaggle/input/mvtec-ad/screw/train/good/154.png
# /kaggle/input/mvtec-ad/screw/train/good/267.png
# /kaggle/input/mvtec-ad/screw/train/good/063.png
# /kaggle/input/mvtec-ad/screw/train/good/022.png
# /kaggle/input/mvtec-ad/screw/train/good/241.png
# /kaggle/input/mvtec-ad/screw/train/good/188.png
# ...
# /kaggle/input/mvtec-ad/cable/test/good/022.png
# /kaggle/input/mvtec-ad/cable/test/good/030.png
# /kaggle/input/mvtec-ad/cable/test/good/056.png
# /kaggle/input/mvtec-ad/cable/test/good/044.png
# /kaggle/input/mvtec-ad/cable/test/good/001.png
# /kaggle/input/mvtec-ad/cable/test/good/047.png
# /kaggle/input/mvtec-ad/cable/test/good/012.png
# /kaggle/input/mvtec-ad/cable/test/good/009.png
# /kaggle/input/mvtec-ad/cable/test/good/050.png
# /kaggle/input/mvtec-ad/cable/test/good/010.png
# /kaggle/input/mvtec-ad/cable/test/good/021.png
# /kaggle/input/mvtec-ad/cable/test/good/008.png
# /kaggle/input/mvtec-ad/cable/test/good/006.png
# /kaggle/input/mvtec-ad/cable/test/good/014.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/007.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/005.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/011.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/013.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/004.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/002.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/000.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/003.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/001.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/012.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/009.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/010.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/008.png
# /kaggle/input/mvtec-ad/cable/test/cut_inner_insulation/006.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/007.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/005.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/011.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/004.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/002.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/000.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/003.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/001.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/009.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/010.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/008.png
# /kaggle/input/mvtec-ad/cable/test/cable_swap/006.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/007.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/005.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/011.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/004.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/002.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/000.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/003.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/001.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/012.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/009.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/010.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/008.png
# /kaggle/input/mvtec-ad/cable/test/bent_wire/006.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/007.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/005.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/004.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/002.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/000.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/003.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/001.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/009.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/008.png
# /kaggle/input/mvtec-ad/cable/test/missing_wire/006.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/007.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/005.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/011.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/004.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/002.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/000.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/003.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/001.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/009.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/010.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/008.png
# /kaggle/input/mvtec-ad/cable/test/missing_cable/006.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/007.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/005.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/004.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/002.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/000.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/003.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/001.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/009.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/008.png
# /kaggle/input/mvtec-ad/cable/test/poke_insulation/006.png
# /kaggle/input/mvtec-ad/cable/test/combined/007.png
# /kaggle/input/mvtec-ad/cable/test/combined/005.png
# /kaggle/input/mvtec-ad/cable/test/combined/004.png
# /kaggle/input/mvtec-ad/cable/test/combined/002.png
# /kaggle/input/mvtec-ad/cable/test/combined/000.png
# /kaggle/input/mvtec-ad/cable/test/combined/003.png
# /kaggle/input/mvtec-ad/cable/test/combined/001.png
# /kaggle/input/mvtec-ad/cable/test/combined/009.png
# /kaggle/input/mvtec-ad/cable/test/combined/010.png
# /kaggle/input/mvtec-ad/cable/test/combined/008.png
# /kaggle/input/mvtec-ad/cable/test/combined/006.png
# /kaggle/input/mvtec-ad/cable/train/good/173.png
# /kaggle/input/mvtec-ad/cable/train/good/043.png
# /kaggle/input/mvtec-ad/cable/train/good/038.png
# /kaggle/input/mvtec-ad/cable/train/good/069.png
# /kaggle/input/mvtec-ad/cable/train/good/083.png
# /kaggle/input/mvtec-ad/cable/train/good/074.png
# /kaggle/input/mvtec-ad/cable/train/good/222.png
# /kaggle/input/mvtec-ad/cable/train/good/027.png
# /kaggle/input/mvtec-ad/cable/train/good/148.png
# /kaggle/input/mvtec-ad/cable/train/good/177.png
# /kaggle/input/mvtec-ad/cable/train/good/142.png
# /kaggle/input/mvtec-ad/cable/train/good/104.png
# /kaggle/input/mvtec-ad/cable/train/good/053.png
# /kaggle/input/mvtec-ad/cable/train/good/007.png
# /kaggle/input/mvtec-ad/cable/train/good/133.png
# /kaggle/input/mvtec-ad/cable/train/good/162.png
# /kaggle/input/mvtec-ad/cable/train/good/186.png
# /kaggle/input/mvtec-ad/cable/train/good/089.png
# /kaggle/input/mvtec-ad/cable/train/good/153.png
# /kaggle/input/mvtec-ad/cable/train/good/023.png
# /kaggle/input/mvtec-ad/cable/train/good/167.png
# /kaggle/input/mvtec-ad/cable/train/good/092.png
# /kaggle/input/mvtec-ad/cable/train/good/061.png
# /kaggle/input/mvtec-ad/cable/train/good/204.png
# /kaggle/input/mvtec-ad/cable/train/good/016.png
# /kaggle/input/mvtec-ad/cable/train/good/081.png
# /kaggle/input/mvtec-ad/cable/train/good/005.png
# /kaggle/input/mvtec-ad/cable/train/good/031.png
# /kaggle/input/mvtec-ad/cable/train/good/164.png
# /kaggle/input/mvtec-ad/cable/train/good/011.png
# /kaggle/input/mvtec-ad/cable/train/good/213.png
# /kaggle/input/mvtec-ad/cable/train/good/114.png
# /kaggle/input/mvtec-ad/cable/train/good/185.png
# /kaggle/input/mvtec-ad/cable/train/good/013.png
# /kaggle/input/mvtec-ad/cable/train/good/176.png
# /kaggle/input/mvtec-ad/cable/train/good/124.png
# /kaggle/input/mvtec-ad/cable/train/good/119.png
# /kaggle/input/mvtec-ad/cable/train/good/046.png
# /kaggle/input/mvtec-ad/cable/train/good/100.png
# /kaggle/input/mvtec-ad/cable/train/good/211.png
# /kaggle/input/mvtec-ad/cable/train/good/193.png
# /kaggle/input/mvtec-ad/cable/train/good/191.png
# /kaggle/input/mvtec-ad/cable/train/good/039.png
# /kaggle/input/mvtec-ad/cable/train/good/163.png
# /kaggle/input/mvtec-ad/cable/train/good/042.png
# /kaggle/input/mvtec-ad/cable/train/good/138.png
# /kaggle/input/mvtec-ad/cable/train/good/024.png
# /kaggle/input/mvtec-ad/cable/train/good/052.png
# /kaggle/input/mvtec-ad/cable/train/good/057.png
# /kaggle/input/mvtec-ad/cable/train/good/192.png
# /kaggle/input/mvtec-ad/cable/train/good/090.png
# /kaggle/input/mvtec-ad/cable/train/good/025.png
# /kaggle/input/mvtec-ad/cable/train/good/129.png
# /kaggle/input/mvtec-ad/cable/train/good/017.png
# /kaggle/input/mvtec-ad/cable/train/good/171.png
# /kaggle/input/mvtec-ad/cable/train/good/145.png
# /kaggle/input/mvtec-ad/cable/train/good/209.png
# /kaggle/input/mvtec-ad/cable/train/good/197.png
# /kaggle/input/mvtec-ad/cable/train/good/126.png
# /kaggle/input/mvtec-ad/cable/train/good/147.png
# /kaggle/input/mvtec-ad/cable/train/good/075.png
# /kaggle/input/mvtec-ad/cable/train/good/102.png
# /kaggle/input/mvtec-ad/cable/train/good/168.png
# /kaggle/input/mvtec-ad/cable/train/good/054.png
# /kaggle/input/mvtec-ad/cable/train/good/200.png
# /kaggle/input/mvtec-ad/cable/train/good/067.png
# /kaggle/input/mvtec-ad/cable/train/good/004.png
# /kaggle/input/mvtec-ad/cable/train/good/033.png
# /kaggle/input/mvtec-ad/cable/train/good/116.png
# /kaggle/input/mvtec-ad/cable/train/good/130.png
# /kaggle/input/mvtec-ad/cable/train/good/091.png
# /kaggle/input/mvtec-ad/cable/train/good/218.png
# /kaggle/input/mvtec-ad/cable/train/good/199.png
# /kaggle/input/mvtec-ad/cable/train/good/112.png
# /kaggle/input/mvtec-ad/cable/train/good/049.png
# /kaggle/input/mvtec-ad/cable/train/good/150.png
# /kaggle/input/mvtec-ad/cable/train/good/070.png
# /kaggle/input/mvtec-ad/cable/train/good/064.png
# /kaggle/input/mvtec-ad/cable/train/good/113.png
# /kaggle/input/mvtec-ad/cable/train/good/169.png
# /kaggle/input/mvtec-ad/cable/train/good/170.png
# /kaggle/input/mvtec-ad/cable/train/good/194.png
# /kaggle/input/mvtec-ad/cable/train/good/136.png
# /kaggle/input/mvtec-ad/cable/train/good/018.png
# /kaggle/input/mvtec-ad/cable/train/good/198.png
# /kaggle/input/mvtec-ad/cable/train/good/045.png
# /kaggle/input/mvtec-ad/cable/train/good/161.png
# /kaggle/input/mvtec-ad/cable/train/good/002.png
# /kaggle/input/mvtec-ad/cable/train/good/108.png
# /kaggle/input/mvtec-ad/cable/train/good/093.png
# /kaggle/input/mvtec-ad/cable/train/good/132.png
# /kaggle/input/mvtec-ad/cable/train/good/156.png
# /kaggle/input/mvtec-ad/cable/train/good/040.png
# /kaggle/input/mvtec-ad/cable/train/good/035.png
# /kaggle/input/mvtec-ad/cable/train/good/094.png
# /kaggle/input/mvtec-ad/cable/train/good/107.png
# /kaggle/input/mvtec-ad/cable/train/good/215.png
# /kaggle/input/mvtec-ad/cable/train/good/181.png
# /kaggle/input/mvtec-ad/cable/train/good/151.png
# /kaggle/input/mvtec-ad/cable/train/good/068.png
# /kaggle/input/mvtec-ad/cable/train/good/048.png
# /kaggle/input/mvtec-ad/cable/train/good/223.png
# /kaggle/input/mvtec-ad/cable/train/good/020.png
# /kaggle/input/mvtec-ad/cable/train/good/174.png
# /kaggle/input/mvtec-ad/cable/train/good/071.png
# /kaggle/input/mvtec-ad/cable/train/good/131.png
# /kaggle/input/mvtec-ad/cable/train/good/041.png
# /kaggle/input/mvtec-ad/cable/train/good/157.png
# /kaggle/input/mvtec-ad/cable/train/good/182.png
# /kaggle/input/mvtec-ad/cable/train/good/143.png
# /kaggle/input/mvtec-ad/cable/train/good/034.png
# /kaggle/input/mvtec-ad/cable/train/good/221.png
# /kaggle/input/mvtec-ad/cable/train/good/208.png
# /kaggle/input/mvtec-ad/cable/train/good/152.png
# /kaggle/input/mvtec-ad/cable/train/good/137.png
# /kaggle/input/mvtec-ad/cable/train/good/076.png
# /kaggle/input/mvtec-ad/cable/train/good/079.png
# /kaggle/input/mvtec-ad/cable/train/good/214.png
# /kaggle/input/mvtec-ad/cable/train/good/122.png
# /kaggle/input/mvtec-ad/cable/train/good/051.png
# /kaggle/input/mvtec-ad/cable/train/good/187.png
# /kaggle/input/mvtec-ad/cable/train/good/106.png
# /kaggle/input/mvtec-ad/cable/train/good/117.png
# /kaggle/input/mvtec-ad/cable/train/good/220.png
# /kaggle/input/mvtec-ad/cable/train/good/032.png
# /kaggle/input/mvtec-ad/cable/train/good/095.png
# /kaggle/input/mvtec-ad/cable/train/good/055.png
# /kaggle/input/mvtec-ad/cable/train/good/037.png
# /kaggle/input/mvtec-ad/cable/train/good/166.png
# /kaggle/input/mvtec-ad/cable/train/good/029.png
# /kaggle/input/mvtec-ad/cable/train/good/088.png
# /kaggle/input/mvtec-ad/cable/train/good/028.png
# /kaggle/input/mvtec-ad/cable/train/good/026.png
# /kaggle/input/mvtec-ad/cable/train/good/066.png
# /kaggle/input/mvtec-ad/cable/train/good/127.png
# /kaggle/input/mvtec-ad/cable/train/good/219.png
# /kaggle/input/mvtec-ad/cable/train/good/073.png
# /kaggle/input/mvtec-ad/cable/train/good/184.png
# /kaggle/input/mvtec-ad/cable/train/good/000.png
# /kaggle/input/mvtec-ad/cable/train/good/019.png
# /kaggle/input/mvtec-ad/cable/train/good/003.png
# /kaggle/input/mvtec-ad/cable/train/good/036.png
# /kaggle/input/mvtec-ad/cable/train/good/190.png
# /kaggle/input/mvtec-ad/cable/train/good/165.png
# /kaggle/input/mvtec-ad/cable/train/good/015.png
# /kaggle/input/mvtec-ad/cable/train/good/202.png
# /kaggle/input/mvtec-ad/cable/train/good/060.png
# /kaggle/input/mvtec-ad/cable/train/good/159.png
# /kaggle/input/mvtec-ad/cable/train/good/195.png
# /kaggle/input/mvtec-ad/cable/train/good/105.png
# /kaggle/input/mvtec-ad/cable/train/good/125.png
# /kaggle/input/mvtec-ad/cable/train/good/121.png
# /kaggle/input/mvtec-ad/cable/train/good/216.png
# /kaggle/input/mvtec-ad/cable/train/good/146.png
# /kaggle/input/mvtec-ad/cable/train/good/154.png
# /kaggle/input/mvtec-ad/cable/train/good/063.png
# /kaggle/input/mvtec-ad/cable/train/good/022.png
# /kaggle/input/mvtec-ad/cable/train/good/188.png
# /kaggle/input/mvtec-ad/cable/train/good/030.png
# /kaggle/input/mvtec-ad/cable/train/good/103.png
# /kaggle/input/mvtec-ad/cable/train/good/144.png
# /kaggle/input/mvtec-ad/cable/train/good/109.png
# /kaggle/input/mvtec-ad/cable/train/good/080.png
# /kaggle/input/mvtec-ad/cable/train/good/120.png
# /kaggle/input/mvtec-ad/cable/train/good/118.png
# /kaggle/input/mvtec-ad/cable/train/good/056.png
# /kaggle/input/mvtec-ad/cable/train/good/078.png
# /kaggle/input/mvtec-ad/cable/train/good/072.png
# /kaggle/input/mvtec-ad/cable/train/good/196.png
# /kaggle/input/mvtec-ad/cable/train/good/044.png
# /kaggle/input/mvtec-ad/cable/train/good/179.png
# /kaggle/input/mvtec-ad/cable/train/good/178.png
# /kaggle/input/mvtec-ad/cable/train/good/086.png
# /kaggle/input/mvtec-ad/cable/train/good/160.png
# /kaggle/input/mvtec-ad/cable/train/good/140.png
# /kaggle/input/mvtec-ad/cable/train/good/139.png
# /kaggle/input/mvtec-ad/cable/train/good/172.png
# /kaggle/input/mvtec-ad/cable/train/good/001.png
# /kaggle/input/mvtec-ad/cable/train/good/047.png
# /kaggle/input/mvtec-ad/cable/train/good/097.png
# /kaggle/input/mvtec-ad/cable/train/good/203.png
# /kaggle/input/mvtec-ad/cable/train/good/087.png
# /kaggle/input/mvtec-ad/cable/train/good/077.png
# /kaggle/input/mvtec-ad/cable/train/good/115.png
# /kaggle/input/mvtec-ad/cable/train/good/128.png
# /kaggle/input/mvtec-ad/cable/train/good/158.png
# /kaggle/input/mvtec-ad/cable/train/good/012.png
# /kaggle/input/mvtec-ad/cable/train/good/085.png
# /kaggle/input/mvtec-ad/cable/train/good/082.png
# /kaggle/input/mvtec-ad/cable/train/good/101.png
# /kaggle/input/mvtec-ad/cable/train/good/009.png
# /kaggle/input/mvtec-ad/cable/train/good/135.png
# /kaggle/input/mvtec-ad/cable/train/good/065.png
# /kaggle/input/mvtec-ad/cable/train/good/123.png
# /kaggle/input/mvtec-ad/cable/train/good/189.png
# /kaggle/input/mvtec-ad/cable/train/good/059.png
# /kaggle/input/mvtec-ad/cable/train/good/180.png
# /kaggle/input/mvtec-ad/cable/train/good/062.png
# /kaggle/input/mvtec-ad/cable/train/good/210.png
# /kaggle/input/mvtec-ad/cable/train/good/183.png
# /kaggle/input/mvtec-ad/cable/train/good/098.png
# /kaggle/input/mvtec-ad/cable/train/good/096.png
# /kaggle/input/mvtec-ad/cable/train/good/155.png
# /kaggle/input/mvtec-ad/cable/train/good/201.png
# /kaggle/input/mvtec-ad/cable/train/good/212.png
# /kaggle/input/mvtec-ad/cable/train/good/207.png
# /kaggle/input/mvtec-ad/cable/train/good/149.png
# /kaggle/input/mvtec-ad/cable/train/good/084.png
# /kaggle/input/mvtec-ad/cable/train/good/099.png
# /kaggle/input/mvtec-ad/cable/train/good/206.png
# /kaggle/input/mvtec-ad/cable/train/good/050.png
# /kaggle/input/mvtec-ad/cable/train/good/010.png
# /kaggle/input/mvtec-ad/cable/train/good/021.png
# /kaggle/input/mvtec-ad/cable/train/good/134.png
# /kaggle/input/mvtec-ad/cable/train/good/111.png
# /kaggle/input/mvtec-ad/cable/train/good/205.png
# /kaggle/input/mvtec-ad/cable/train/good/141.png
# /kaggle/input/mvtec-ad/cable/train/good/110.png
# /kaggle/input/mvtec-ad/cable/train/good/008.png
# /kaggle/input/mvtec-ad/cable/train/good/006.png
# /kaggle/input/mvtec-ad/cable/train/good/058.png
# /kaggle/input/mvtec-ad/cable/train/good/175.png
# /kaggle/input/mvtec-ad/cable/train/good/014.png
# /kaggle/input/mvtec-ad/cable/train/good/217.png

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import cv2
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torchvision.datasets import ImageFolder
import torch.optim as optim
import os
from torchvision.io import read_image
from PIL import Image

# %%
class textile(Dataset):
    def __init__(self,root_dir,train=True,transform=None):
        self.root_dir = root_dir
        self.train = train
        self.transform = transform
        self.image_paths = []

        if self.train:
            normal_dir = os.path.join(root_dir,"train","good")
            for filename in os.listdir(normal_dir):
                if filename.endswith('.png'):
                    self.image_paths.append(os.path.join(normal_dir,filename))
        else:
            for subfolder in os.listdir('/kaggle/input/mvtec-ad/carpet/test'): #This will include all subfolders
                test_dir = os.path.join(root_dir,'test',subfolder)
                for filename in os.listdir(test_dir):
                    if filename.endswith('.png'):
                        self.image_paths.append(os.path.join(test_dir,filename))
    def __len__(self):
        return len(self.image_paths)
    def __getitem__(self,idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        
        if self.transform:
            image = self.transform(image)
        return image

# %%
image_size = 256
transform_func = transforms.Compose([
    # transforms.ToPILImage(), #convert to PIL image to handle transforms
    transforms.Resize(image_size),
    transforms.ToTensor(), #convert back to tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
os.chdir('/kaggle/input/mvtec-ad')

# %%
train_dataset = textile(root_dir='carpet',transform=transform_func,train=True)
test_dataset = textile(root_dir='carpet',transform=transform_func,train=False)

# %%
plt.imshow(cv2.imread('/kaggle/input/mvtec-ad/carpet/train/good/000.png'))

# %%
plt.imshow(train_dataset[0].permute(1,2,0).cpu().numpy())

# %%
train_loader = DataLoader(train_dataset,batch_size=16,shuffle=True)
test_loader = DataLoader(test_dataset,batch_size=16,shuffle=False)

# %%
class SimpleEncoder(nn.Module):
    def __init__(self):
        super(SimpleEncoder,self).__init__()
        #Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3,32,3,1,1),
            nn.LeakyReLU(),
            nn.Conv2d(32,64,3,1,1),
            nn.LeakyReLU(),
            nn.Conv2d(64,128,3,1,1),
            nn.LeakyReLU(),
            nn.Conv2d(128,256,3,1,1),
            nn.LeakyReLU()
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256,128,3,1,1),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(128,64,3,1,1),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(64,32,3,1,1),
            nn.LeakyReLU(),
            nn.ConvTranspose2d(32,3,3,1,1),
            nn.Sigmoid(),
        ) 

    def forward(self,x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model = SimpleEncoder().to(device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-55-2979aabce9ac> in <cell line: 1>()
# ----> 1 model = SimpleEncoder().to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1172                     raise
#    1173
# -> 1174         return self._apply(convert)
#    1175
#    1176     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     778         if recurse:
#     779             for module in self.children():
# --> 780                 module._apply(fn)
#     781
#     782         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     803             # `with torch.no_grad():`
#     804             with torch.no_grad():
# --> 805                 param_applied = fn(param)
#     806             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     807
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in convert(t)
#    1158                         memory_format=convert_to_format,
#    1159                     )
# -> 1160                 return t.to(
#    1161                     device,
#    1162                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
#hyper param
optimizer = optim.Adam(model.parameters(),lr = 1e-04)
# loss_fn = nn.BCELoss()
loss_fn = nn.MSELoss()
# from pytorch_msssim import SSIM
# loss_fn = SSIM()
epochs = 10

# %%
train_losses = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    for batch in train_loader:
        batch = batch.to(device)
        # optimizer.zero_grad()

        pred = model(batch)
        # print(pred.shape)
        # print(batch.shape)
        loss = loss_fn(pred,batch)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        train_loss += loss.item()
    avg_loss = train_loss/len(train_loader)
    print(f'Epoch: {epoch} | Loss: {avg_loss}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-167f4ef10665> in <cell line: 3>()
#       5     train_loss = 0
#       6     for batch in train_loader:
# ----> 7         batch = batch.to(device)
#       8         optimizer.zero_grad()
#       9
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from PIL import Image
from torchvision import transforms

# Path to a test image (defect category)
test_image_path = "/kaggle/input/mvtec-ad/carpet/test/thread/010.png"  # Replace with actual path

# Load and preprocess the test image
def preprocess_image(image_path, image_size=(128, 128)):  # Ensure the size matches the model input
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor(),  # Convert image to tensor
        # transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalize to [-1, 1] range
    ])
    image = Image.open(image_path).convert("RGB")  # Open and ensure it's in RGB format
    return transform(image).unsqueeze(0)  # Add batch dimension

# Load the test image
test_image = preprocess_image(test_image_path)

# Pass the test image through the autoencoder
model.eval()  # Set model to evaluation mode
with torch.no_grad():
    reconstructed_image = model(test_image.to(device))

# Check the shapes of the tensors before squeezing
print(f"Original test image shape: {test_image.shape}")
print(f"Reconstructed image shape: {reconstructed_image.shape}")

# Ensure we only squeeze the batch dimension if it exists (i.e., batch size = 1)
if test_image.dim() == 4:  # Check if there is a batch dimension
    test_image_np = test_image.squeeze(0).permute(1, 2, 0).cpu().numpy()
else:
    test_image_np = test_image.permute(1, 2, 0).cpu().numpy()

if reconstructed_image.dim() == 4:  # Check if there is a batch dimension
    reconstructed_image_np = reconstructed_image.squeeze(0).permute(1, 2, 0).cpu().numpy()
else:
    reconstructed_image_np = reconstructed_image.permute(1, 2, 0).cpu().numpy()

# De-normalize (if normalization was applied during preprocessing)
# test_image_np = (test_image_np * 0.5) + 0.5  # Reverse normalization to [0, 1]
# reconstructed_image_np = (reconstructed_image_np * 0.5) + 0.5

# Visualize the original and reconstructed images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(test_image_np)
plt.title("Original Test Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(reconstructed_image_np)
plt.title("Reconstructed Image")
plt.axis("off")

plt.show()

# Compute the reconstruction error (Mean Squared Error)
def compute_reconstruction_error(original, reconstructed):
    # Compute the MSE (Mean Squared Error) between the original and reconstructed image
    return torch.mean((original - reconstructed) ** 2)

# Convert images to tensors for error calculation (remove batch dimension)
if test_image.dim() == 4:
    test_image_tensor = test_image.squeeze(0)
else:
    test_image_tensor = test_image

if reconstructed_image.dim() == 4:
    reconstructed_image_tensor = reconstructed_image.squeeze(0)
else:
    reconstructed_image_tensor = reconstructed_image

# Compute the MSE
reconstruction_error = compute_reconstruction_error(test_image_tensor.cpu(), reconstructed_image_tensor.cpu())
print(f"Reconstruction Error: {reconstruction_error.item()}")

# Set a threshold for classification
threshold = 0.1  # This value can be adjusted based on your dataset

# Classify as defective or not based on the reconstruction error
if reconstruction_error.item() > threshold:
    print("The image is likely defective.")
else:
    print("The image is likely normal.")
